# %% [markdown]
# <a href="https://colab.research.google.com/github/nguille0307/n8n-guille/blob/master/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-sn_wjf8h
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-sn_wjf8h
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=10d0533c8d2e563c7570cc64323eb96c17ea0a5316440f06470b9653e145be8d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-echt2t6q/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302722, train error 89.82,  test loss 2.302621, test error 89.57
# Epoch   100, train loss 2.243954, train error 86.60,  test loss 2.268172, test error 87.00
# Epoch   200, train loss 2.231465, train error 86.10,  test loss 2.273998, test error 86.82
# Epoch   300, train loss 2.226999, train error 85.88,  test loss 2.274081, test error 86.93
# Epoch   400, train loss 2.226506, train error 86.10,  test loss 2.273481, test error 87.10
# Epoch   500, train loss 2.223766, train error 86.10,  test loss 2.277094, test error 87.03
# Epoch   600, train loss 2.222432, train error 86.10,  test loss 2.277715, test error 87.20
# Epoch   700, train loss 2.221126, train error 86.12,  test loss 2.277563, test error 87.43
# Epoch   800, train loss 2.220669, train error 86.28,  test loss 2.277767, test error 87.40
# Epoch   900, train loss 2.219491, train error 86.12,  test loss 2.279281, test error 87.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.276481, train error 86.30,  test loss 2.274292, test error 86.62
# Epoch   100, train loss 1.777236, train error 66.72,  test loss 1.630675, test error 65.10
# Epoch   200, train loss 1.752723, train error 64.53,  test loss 1.608092, test error 62.03
# Epoch   300, train loss 1.741513, train error 63.78,  test loss 1.592794, test error 61.67
# Epoch   400, train loss 1.737374, train error 64.15,  test loss 1.590703, test error 61.90
# Epoch   500, train loss 1.734430, train error 64.78,  test loss 1.588174, test error 62.25
# Epoch   600, train loss 1.732311, train error 64.50,  test loss 1.581432, test error 61.42
# Epoch   700, train loss 1.732340, train error 64.57,  test loss 1.591027, test error 62.12
# Epoch   800, train loss 1.732130, train error 63.92,  test loss 1.591742, test error 61.72
# Epoch   900, train loss 1.741088, train error 64.68,  test loss 1.594570, test error 62.28
# Training model with   6 hidden variables
# Epoch     0, train loss 2.220437, train error 84.75,  test loss 2.177620, test error 82.47
# Epoch   100, train loss 1.678841, train error 61.60,  test loss 1.551753, test error 59.42
# Epoch   200, train loss 1.625925, train error 58.20,  test loss 1.493320, test error 57.72
# Epoch   300, train loss 1.608338, train error 57.62,  test loss 1.470896, test error 57.33
# Epoch   400, train loss 1.600563, train error 57.40,  test loss 1.463959, test error 57.78
# Epoch   500, train loss 1.601185, train error 57.40,  test loss 1.468680, test error 57.55
# Epoch   600, train loss 1.595122, train error 57.00,  test loss 1.467195, test error 57.17
# Epoch   700, train loss 1.601562, train error 57.00,  test loss 1.481707, test error 57.30
# Epoch   800, train loss 1.596027, train error 57.17,  test loss 1.482099, test error 57.05
# Epoch   900, train loss 1.589334, train error 56.85,  test loss 1.459886, test error 56.55
# Training model with   8 hidden variables
# Epoch     0, train loss 2.257307, train error 85.00,  test loss 2.258828, test error 86.18
# Epoch   100, train loss 1.613193, train error 57.72,  test loss 1.449410, test error 56.67
# Epoch   200, train loss 1.574463, train error 56.55,  test loss 1.421684, test error 55.60
# Epoch   300, train loss 1.559051, train error 54.88,  test loss 1.418418, test error 54.88
# Epoch   400, train loss 1.551062, train error 54.95,  test loss 1.431113, test error 55.72
# Epoch   500, train loss 1.545075, train error 54.42,  test loss 1.434862, test error 55.72
# Epoch   600, train loss 1.539771, train error 55.12,  test loss 1.447070, test error 56.15
# Epoch   700, train loss 1.539257, train error 54.53,  test loss 1.456756, test error 55.35
# Epoch   800, train loss 1.535720, train error 54.88,  test loss 1.449311, test error 55.50
# Epoch   900, train loss 1.535182, train error 54.40,  test loss 1.455869, test error 55.15
# Training model with  10 hidden variables
# Epoch     0, train loss 2.287049, train error 88.28,  test loss 2.287960, test error 87.82
# Epoch   100, train loss 1.464493, train error 49.65,  test loss 1.280123, test error 47.35
# Epoch   200, train loss 1.431113, train error 48.78,  test loss 1.260055, test error 46.65
# Epoch   300, train loss 1.408949, train error 47.55,  test loss 1.259071, test error 46.80
# Epoch   400, train loss 1.406684, train error 48.25,  test loss 1.268915, test error 46.92
# Epoch   500, train loss 1.395014, train error 47.92,  test loss 1.270777, test error 47.08
# Epoch   600, train loss 1.394691, train error 47.12,  test loss 1.286341, test error 47.33
# Epoch   700, train loss 1.397729, train error 48.05,  test loss 1.298044, test error 47.40
# Epoch   800, train loss 1.387871, train error 47.60,  test loss 1.297612, test error 46.70
# Epoch   900, train loss 1.385041, train error 47.40,  test loss 1.304347, test error 47.45
# Training model with  14 hidden variables
# Epoch     0, train loss 2.262954, train error 84.72,  test loss 2.245467, test error 83.70
# Epoch   100, train loss 1.450191, train error 48.67,  test loss 1.336969, test error 49.40
# Epoch   200, train loss 1.352603, train error 45.60,  test loss 1.305899, test error 49.00
# Epoch   300, train loss 1.312803, train error 44.33,  test loss 1.341798, test error 49.72
# Epoch   400, train loss 1.300928, train error 43.28,  test loss 1.364231, test error 50.35
# Epoch   500, train loss 1.293588, train error 43.12,  test loss 1.378636, test error 51.42
# Epoch   600, train loss 1.287173, train error 43.20,  test loss 1.370766, test error 50.72
# Epoch   700, train loss 1.282245, train error 43.15,  test loss 1.393112, test error 50.95
# Epoch   800, train loss 1.273849, train error 42.97,  test loss 1.397565, test error 50.62
# Epoch   900, train loss 1.271054, train error 42.67,  test loss 1.400122, test error 51.03
# Training model with  18 hidden variables
# Epoch     0, train loss 2.198571, train error 80.97,  test loss 2.176588, test error 80.45
# Epoch   100, train loss 1.355465, train error 45.67,  test loss 1.343553, test error 51.58
# Epoch   200, train loss 1.246928, train error 41.10,  test loss 1.349931, test error 50.53
# Epoch   300, train loss 1.203079, train error 40.33,  test loss 1.410365, test error 50.28
# Epoch   400, train loss 1.176144, train error 39.50,  test loss 1.436191, test error 50.95
# Epoch   500, train loss 1.161379, train error 39.55,  test loss 1.492430, test error 51.58
# Epoch   600, train loss 1.150355, train error 38.25,  test loss 1.526675, test error 51.83
# Epoch   700, train loss 1.136052, train error 37.95,  test loss 1.534977, test error 51.62
# Epoch   800, train loss 1.130177, train error 37.35,  test loss 1.555222, test error 51.70
# Epoch   900, train loss 1.125515, train error 37.38,  test loss 1.581291, test error 51.20
# Training model with  22 hidden variables
# Epoch     0, train loss 2.159626, train error 80.40,  test loss 2.121536, test error 79.55
# Epoch   100, train loss 1.262478, train error 42.12,  test loss 1.312092, test error 48.42
# Epoch   200, train loss 1.147628, train error 38.62,  test loss 1.373127, test error 49.45
# Epoch   300, train loss 1.087930, train error 37.30,  test loss 1.433092, test error 49.67
# Epoch   400, train loss 1.065275, train error 36.85,  test loss 1.492542, test error 50.70
# Epoch   500, train loss 1.037005, train error 35.07,  test loss 1.531666, test error 50.75
# Epoch   600, train loss 1.020654, train error 34.35,  test loss 1.594765, test error 50.88
# Epoch   700, train loss 1.010485, train error 33.53,  test loss 1.623360, test error 50.72
# Epoch   800, train loss 1.004037, train error 34.25,  test loss 1.674537, test error 52.10
# Epoch   900, train loss 0.997884, train error 34.30,  test loss 1.716739, test error 52.75
# Training model with  26 hidden variables
# Epoch     0, train loss 2.190630, train error 81.05,  test loss 2.183372, test error 81.57
# Epoch   100, train loss 1.175416, train error 38.80,  test loss 1.343969, test error 48.95
# Epoch   200, train loss 1.018670, train error 33.78,  test loss 1.497604, test error 51.60
# Epoch   300, train loss 0.958394, train error 32.32,  test loss 1.634485, test error 51.85
# Epoch   400, train loss 0.907048, train error 30.43,  test loss 1.730473, test error 52.65
# Epoch   500, train loss 0.885928, train error 29.35,  test loss 1.841725, test error 53.58
# Epoch   600, train loss 0.868863, train error 29.25,  test loss 1.882490, test error 53.62
# Epoch   700, train loss 0.847762, train error 28.28,  test loss 1.948951, test error 53.97
# Epoch   800, train loss 0.828606, train error 26.72,  test loss 2.014672, test error 54.35
# Epoch   900, train loss 0.826714, train error 27.43,  test loss 2.096210, test error 55.10
# Training model with  30 hidden variables
# Epoch     0, train loss 2.170512, train error 80.30,  test loss 2.123491, test error 78.75
# Epoch   100, train loss 1.113753, train error 36.90,  test loss 1.366059, test error 48.90
# Epoch   200, train loss 0.912269, train error 30.45,  test loss 1.552251, test error 50.70
# Epoch   300, train loss 0.812267, train error 26.78,  test loss 1.761057, test error 51.72
# Epoch   400, train loss 0.767198, train error 25.40,  test loss 1.887296, test error 52.25
# Epoch   500, train loss 0.765621, train error 26.55,  test loss 2.020625, test error 52.72
# Epoch   600, train loss 0.715891, train error 24.15,  test loss 2.122518, test error 52.85
# Epoch   700, train loss 0.715720, train error 24.60,  test loss 2.247510, test error 53.55
# Epoch   800, train loss 0.687863, train error 23.53,  test loss 2.326314, test error 54.05
# Epoch   900, train loss 0.658383, train error 22.78,  test loss 2.486582, test error 54.95
# Training model with  35 hidden variables
# Epoch     0, train loss 2.150674, train error 78.75,  test loss 2.155041, test error 78.38
# Epoch   100, train loss 1.007284, train error 32.60,  test loss 1.332586, test error 47.25
# Epoch   200, train loss 0.781592, train error 25.53,  test loss 1.667159, test error 51.35
# Epoch   300, train loss 0.673639, train error 21.68,  test loss 1.998198, test error 52.97
# Epoch   400, train loss 0.582060, train error 19.22,  test loss 2.441649, test error 55.00
# Epoch   500, train loss 0.531770, train error 17.70,  test loss 2.855899, test error 55.00
# Epoch   600, train loss 0.547116, train error 18.88,  test loss 3.300355, test error 57.33
# Epoch   700, train loss 0.502358, train error 17.25,  test loss 3.553917, test error 56.12
# Epoch   800, train loss 0.467503, train error 16.47,  test loss 3.802873, test error 56.60
# Epoch   900, train loss 0.452174, train error 15.85,  test loss 4.097562, test error 56.88
# Training model with  40 hidden variables
# Epoch     0, train loss 2.132435, train error 78.57,  test loss 2.113853, test error 78.75
# Epoch   100, train loss 0.869436, train error 28.38,  test loss 1.386834, test error 48.03
# Epoch   200, train loss 0.605828, train error 19.32,  test loss 1.974185, test error 51.45
# Epoch   300, train loss 0.466179, train error 15.60,  test loss 2.687846, test error 53.75
# Epoch   400, train loss 0.394169, train error 13.45,  test loss 3.531983, test error 55.33
# Epoch   500, train loss 0.310406, train error 10.62,  test loss 4.317907, test error 56.42
# Epoch   600, train loss 0.291670, train error 10.78,  test loss 5.161037, test error 56.38
# Epoch   700, train loss 0.263451, train error 9.57,  test loss 5.864840, test error 57.08
# Epoch   800, train loss 0.216094, train error 7.47,  test loss 6.680539, test error 57.75
# Epoch   900, train loss 0.233219, train error 8.68,  test loss 7.345038, test error 57.03
# Training model with  45 hidden variables
# Epoch     0, train loss 2.104758, train error 78.28,  test loss 2.050854, test error 75.90
# Epoch   100, train loss 0.826224, train error 25.85,  test loss 1.469716, test error 49.22
# Epoch   200, train loss 0.512349, train error 16.38,  test loss 2.142458, test error 52.25
# Epoch   300, train loss 0.383065, train error 13.18,  test loss 3.157079, test error 54.05
# Epoch   400, train loss 0.204850, train error 5.75,  test loss 4.248010, test error 55.28
# Epoch   500, train loss 0.175247, train error 5.60,  test loss 5.320100, test error 55.05
# Epoch   600, train loss 0.226845, train error 7.80,  test loss 6.481326, test error 55.95
# Epoch   700, train loss 0.224977, train error 8.20,  test loss 7.619178, test error 55.70
# Epoch   800, train loss 0.223964, train error 7.43,  test loss 8.471978, test error 55.85
# Epoch   900, train loss 0.005670, train error 0.00,  test loss 9.130982, test error 55.33
# Training model with  50 hidden variables
# Epoch     0, train loss 2.077297, train error 78.35,  test loss 2.007963, test error 75.95
# Epoch   100, train loss 0.702526, train error 22.03,  test loss 1.557840, test error 48.62
# Epoch   200, train loss 0.306077, train error 8.65,  test loss 2.702060, test error 52.95
# Epoch   300, train loss 0.122462, train error 2.28,  test loss 4.312645, test error 54.42
# Epoch   400, train loss 0.027876, train error 0.05,  test loss 5.797534, test error 55.05
# Epoch   500, train loss 0.013195, train error 0.00,  test loss 6.716650, test error 55.10
# Epoch   600, train loss 0.008414, train error 0.00,  test loss 7.335104, test error 55.10
# Epoch   700, train loss 0.006032, train error 0.00,  test loss 7.793542, test error 55.25
# Epoch   800, train loss 0.004629, train error 0.00,  test loss 8.153151, test error 55.40
# Epoch   900, train loss 0.003735, train error 0.00,  test loss 8.462078, test error 55.25
# Training model with  55 hidden variables
# Epoch     0, train loss 2.096085, train error 77.97,  test loss 2.054885, test error 77.88
# Epoch   100, train loss 0.629344, train error 18.70,  test loss 1.723654, test error 52.55
# Epoch   200, train loss 0.188659, train error 4.20,  test loss 3.146837, test error 53.70
# Epoch   300, train loss 0.032917, train error 0.03,  test loss 4.829979, test error 55.17
# Epoch   400, train loss 0.012972, train error 0.00,  test loss 5.765653, test error 55.22
# Epoch   500, train loss 0.007615, train error 0.00,  test loss 6.337133, test error 55.28
# Epoch   600, train loss 0.005292, train error 0.00,  test loss 6.755424, test error 55.25
# Epoch   700, train loss 0.003990, train error 0.00,  test loss 7.083371, test error 55.62
# Epoch   800, train loss 0.003195, train error 0.00,  test loss 7.355252, test error 55.58
# Epoch   900, train loss 0.002619, train error 0.00,  test loss 7.584234, test error 55.45
# Training model with  60 hidden variables
# Epoch     0, train loss 2.057363, train error 76.65,  test loss 2.005037, test error 76.95
# Epoch   100, train loss 0.537047, train error 16.25,  test loss 1.769969, test error 49.85
# Epoch   200, train loss 0.094444, train error 0.72,  test loss 3.347479, test error 53.10
# Epoch   300, train loss 0.018239, train error 0.00,  test loss 4.596927, test error 53.42
# Epoch   400, train loss 0.008886, train error 0.00,  test loss 5.226936, test error 53.30
# Epoch   500, train loss 0.005692, train error 0.00,  test loss 5.642560, test error 53.22
# Epoch   600, train loss 0.004081, train error 0.00,  test loss 5.957398, test error 53.33
# Epoch   700, train loss 0.003144, train error 0.00,  test loss 6.209652, test error 53.22
# Epoch   800, train loss 0.002531, train error 0.00,  test loss 6.413724, test error 53.17
# Epoch   900, train loss 0.002105, train error 0.00,  test loss 6.593226, test error 53.22
# Training model with  70 hidden variables
# Epoch     0, train loss 2.077722, train error 77.50,  test loss 2.054624, test error 76.15
# Epoch   100, train loss 0.351246, train error 8.47,  test loss 1.986002, test error 52.10
# Epoch   200, train loss 0.032171, train error 0.00,  test loss 3.665075, test error 54.12
# Epoch   300, train loss 0.010721, train error 0.00,  test loss 4.435725, test error 54.12
# Epoch   400, train loss 0.005981, train error 0.00,  test loss 4.871209, test error 54.35
# Epoch   500, train loss 0.004038, train error 0.00,  test loss 5.170421, test error 54.35
# Epoch   600, train loss 0.002994, train error 0.00,  test loss 5.400675, test error 54.45
# Epoch   700, train loss 0.002349, train error 0.00,  test loss 5.585351, test error 54.22
# Epoch   800, train loss 0.001921, train error 0.00,  test loss 5.741681, test error 54.40
# Epoch   900, train loss 0.001615, train error 0.00,  test loss 5.874482, test error 54.40
# Training model with  80 hidden variables
# Epoch     0, train loss 2.003843, train error 74.35,  test loss 1.946558, test error 74.68
# Epoch   100, train loss 0.236900, train error 4.25,  test loss 2.073124, test error 50.55
# Epoch   200, train loss 0.020259, train error 0.00,  test loss 3.467837, test error 52.00
# Epoch   300, train loss 0.008127, train error 0.00,  test loss 4.035316, test error 51.92
# Epoch   400, train loss 0.004800, train error 0.00,  test loss 4.374177, test error 52.00
# Epoch   500, train loss 0.003314, train error 0.00,  test loss 4.614486, test error 52.05
# Epoch   600, train loss 0.002488, train error 0.00,  test loss 4.795917, test error 52.17
# Epoch   700, train loss 0.001973, train error 0.00,  test loss 4.944766, test error 52.00
# Epoch   800, train loss 0.001623, train error 0.00,  test loss 5.072245, test error 51.95
# Epoch   900, train loss 0.001373, train error 0.00,  test loss 5.181550, test error 52.00
# Training model with  90 hidden variables
# Epoch     0, train loss 2.004253, train error 73.35,  test loss 1.945411, test error 75.82
# Epoch   100, train loss 0.149132, train error 1.45,  test loss 2.188882, test error 50.35
# Epoch   200, train loss 0.014943, train error 0.00,  test loss 3.286079, test error 51.28
# Epoch   300, train loss 0.006568, train error 0.00,  test loss 3.734909, test error 51.50
# Epoch   400, train loss 0.003993, train error 0.00,  test loss 4.011357, test error 51.85
# Epoch   500, train loss 0.002803, train error 0.00,  test loss 4.207823, test error 51.75
# Epoch   600, train loss 0.002128, train error 0.00,  test loss 4.362029, test error 51.92
# Epoch   700, train loss 0.001700, train error 0.00,  test loss 4.489082, test error 51.67
# Epoch   800, train loss 0.001406, train error 0.00,  test loss 4.595985, test error 51.70
# Epoch   900, train loss 0.001194, train error 0.00,  test loss 4.687419, test error 51.72
# Training model with 100 hidden variables
# Epoch     0, train loss 1.987146, train error 72.70,  test loss 1.917690, test error 73.68
# Epoch   100, train loss 0.093893, train error 0.28,  test loss 2.257092, test error 50.70
# Epoch   200, train loss 0.012353, train error 0.00,  test loss 3.121866, test error 50.85
# Epoch   300, train loss 0.005738, train error 0.00,  test loss 3.492193, test error 50.90
# Epoch   400, train loss 0.003572, train error 0.00,  test loss 3.721906, test error 50.88
# Epoch   500, train loss 0.002534, train error 0.00,  test loss 3.890250, test error 51.05
# Epoch   600, train loss 0.001939, train error 0.00,  test loss 4.021465, test error 51.10
# Epoch   700, train loss 0.001557, train error 0.00,  test loss 4.131977, test error 51.12
# Epoch   800, train loss 0.001293, train error 0.00,  test loss 4.224053, test error 51.20
# Epoch   900, train loss 0.001101, train error 0.00,  test loss 4.305556, test error 51.22
# Training model with 120 hidden variables
# Epoch     0, train loss 1.984575, train error 73.35,  test loss 1.909916, test error 73.35
# Epoch   100, train loss 0.053051, train error 0.03,  test loss 2.212780, test error 50.75
# Epoch   200, train loss 0.009629, train error 0.00,  test loss 2.809792, test error 50.50
# Epoch   300, train loss 0.004762, train error 0.00,  test loss 3.089581, test error 50.92
# Epoch   400, train loss 0.003037, train error 0.00,  test loss 3.267373, test error 50.85
# Epoch   500, train loss 0.002190, train error 0.00,  test loss 3.399403, test error 50.95
# Epoch   600, train loss 0.001692, train error 0.00,  test loss 3.503618, test error 50.80
# Epoch   700, train loss 0.001368, train error 0.00,  test loss 3.589417, test error 50.80
# Epoch   800, train loss 0.001142, train error 0.00,  test loss 3.662167, test error 50.88
# Epoch   900, train loss 0.000976, train error 0.00,  test loss 3.726833, test error 50.90
# Training model with 140 hidden variables
# Epoch     0, train loss 1.951156, train error 72.28,  test loss 1.890062, test error 72.30
# Epoch   100, train loss 0.037662, train error 0.00,  test loss 2.125134, test error 48.80
# Epoch   200, train loss 0.008271, train error 0.00,  test loss 2.617510, test error 48.70
# Epoch   300, train loss 0.004208, train error 0.00,  test loss 2.849806, test error 48.80
# Epoch   400, train loss 0.002732, train error 0.00,  test loss 3.005488, test error 48.90
# Epoch   500, train loss 0.001982, train error 0.00,  test loss 3.118535, test error 48.85
# Epoch   600, train loss 0.001539, train error 0.00,  test loss 3.209559, test error 48.88
# Epoch   700, train loss 0.001249, train error 0.00,  test loss 3.285141, test error 48.80
# Epoch   800, train loss 0.001046, train error 0.00,  test loss 3.348704, test error 48.75
# Epoch   900, train loss 0.000895, train error 0.00,  test loss 3.404756, test error 48.88
# Training model with 160 hidden variables
# Epoch     0, train loss 1.950314, train error 71.90,  test loss 1.894125, test error 73.90
# Epoch   100, train loss 0.029359, train error 0.00,  test loss 2.096368, test error 49.50
# Epoch   200, train loss 0.007273, train error 0.00,  test loss 2.496340, test error 49.35
# Epoch   300, train loss 0.003807, train error 0.00,  test loss 2.693760, test error 49.35
# Epoch   400, train loss 0.002496, train error 0.00,  test loss 2.821383, test error 49.38
# Epoch   500, train loss 0.001824, train error 0.00,  test loss 2.918913, test error 49.25
# Epoch   600, train loss 0.001423, train error 0.00,  test loss 2.997306, test error 49.33
# Epoch   700, train loss 0.001159, train error 0.00,  test loss 3.061207, test error 49.17
# Epoch   800, train loss 0.000973, train error 0.00,  test loss 3.116724, test error 49.28
# Epoch   900, train loss 0.000835, train error 0.00,  test loss 3.165149, test error 49.28
# Training model with 180 hidden variables
# Epoch     0, train loss 1.946748, train error 71.50,  test loss 1.844577, test error 70.20
# Epoch   100, train loss 0.025840, train error 0.00,  test loss 2.011296, test error 47.35
# Epoch   200, train loss 0.006727, train error 0.00,  test loss 2.363597, test error 47.10
# Epoch   300, train loss 0.003584, train error 0.00,  test loss 2.541751, test error 47.08
# Epoch   400, train loss 0.002368, train error 0.00,  test loss 2.660169, test error 47.08
# Epoch   500, train loss 0.001740, train error 0.00,  test loss 2.749547, test error 47.22
# Epoch   600, train loss 0.001361, train error 0.00,  test loss 2.819904, test error 47.17
# Epoch   700, train loss 0.001110, train error 0.00,  test loss 2.879662, test error 47.12
# Epoch   800, train loss 0.000933, train error 0.00,  test loss 2.930381, test error 47.10
# Epoch   900, train loss 0.000801, train error 0.00,  test loss 2.974896, test error 47.08
# Training model with 200 hidden variables
# Epoch     0, train loss 1.932685, train error 70.85,  test loss 1.867939, test error 72.80
# Epoch   100, train loss 0.021805, train error 0.00,  test loss 2.007137, test error 48.28
# Epoch   200, train loss 0.006172, train error 0.00,  test loss 2.323651, test error 48.38
# Epoch   300, train loss 0.003343, train error 0.00,  test loss 2.485398, test error 48.30
# Epoch   400, train loss 0.002228, train error 0.00,  test loss 2.593008, test error 48.25
# Epoch   500, train loss 0.001645, train error 0.00,  test loss 2.674243, test error 48.28
# Epoch   600, train loss 0.001292, train error 0.00,  test loss 2.740813, test error 48.33
# Epoch   700, train loss 0.001057, train error 0.00,  test loss 2.795235, test error 48.30
# Epoch   800, train loss 0.000890, train error 0.00,  test loss 2.842431, test error 48.25
# Epoch   900, train loss 0.000766, train error 0.00,  test loss 2.883657, test error 48.25
# Training model with 250 hidden variables
# Epoch     0, train loss 1.882379, train error 68.65,  test loss 1.804408, test error 69.65
# Epoch   100, train loss 0.017013, train error 0.00,  test loss 1.948870, test error 47.20
# Epoch   200, train loss 0.005291, train error 0.00,  test loss 2.208895, test error 47.47
# Epoch   300, train loss 0.002952, train error 0.00,  test loss 2.349234, test error 47.42
# Epoch   400, train loss 0.001990, train error 0.00,  test loss 2.442905, test error 47.40
# Epoch   500, train loss 0.001482, train error 0.00,  test loss 2.515150, test error 47.42
# Epoch   600, train loss 0.001170, train error 0.00,  test loss 2.572997, test error 47.45
# Epoch   700, train loss 0.000961, train error 0.00,  test loss 2.621308, test error 47.42
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.663166, test error 47.47
# Epoch   900, train loss 0.000700, train error 0.00,  test loss 2.699636, test error 47.50
# Training model with 300 hidden variables
# Epoch     0, train loss 1.873061, train error 68.05,  test loss 1.818651, test error 70.30
# Epoch   100, train loss 0.014474, train error 0.00,  test loss 1.846237, test error 46.88
# Epoch   200, train loss 0.004796, train error 0.00,  test loss 2.054102, test error 46.83
# Epoch   300, train loss 0.002721, train error 0.00,  test loss 2.167123, test error 46.78
# Epoch   400, train loss 0.001853, train error 0.00,  test loss 2.246113, test error 46.60
# Epoch   500, train loss 0.001387, train error 0.00,  test loss 2.306654, test error 46.65
# Epoch   600, train loss 0.001099, train error 0.00,  test loss 2.355177, test error 46.65
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.396100, test error 46.78
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.431108, test error 46.67
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.461809, test error 46.67
# Training model with 400 hidden variables
# Epoch     0, train loss 1.830006, train error 65.05,  test loss 1.766661, test error 67.55
# Epoch   100, train loss 0.011706, train error 0.00,  test loss 1.758813, test error 45.85
# Epoch   200, train loss 0.004204, train error 0.00,  test loss 1.933164, test error 45.92
# Epoch   300, train loss 0.002436, train error 0.00,  test loss 2.029271, test error 45.95
# Epoch   400, train loss 0.001680, train error 0.00,  test loss 2.097716, test error 46.03
# Epoch   500, train loss 0.001265, train error 0.00,  test loss 2.149475, test error 45.90
# Epoch   600, train loss 0.001007, train error 0.00,  test loss 2.191222, test error 45.80
# Epoch   700, train loss 0.000833, train error 0.00,  test loss 2.227626, test error 45.85
# Epoch   800, train loss 0.000707, train error 0.00,  test loss 2.257773, test error 45.85
# Epoch   900, train loss 0.000612, train error 0.00,  test loss 2.285038, test error 45.85

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
