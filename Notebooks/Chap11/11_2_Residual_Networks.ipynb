# %% [markdown]
# <a href="https://colab.research.google.com/github/nguille0307/n8n-guille/blob/master/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-tcameoff
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-tcameoff
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.5.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=075ef932163de61d6745336f785367717833a336056ec901aa0337439529aaed
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sbbrmzm6/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)
    h2 = h1 + self.linear2(h1).relu()
    h3 = h2 + self.linear3(h2).relu()
    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.696063, train error 62.60,  val loss 1.853345, percent error 67.60
# Epoch     1, train loss 1.205973, train error 45.62,  val loss 1.398096, percent error 54.40
# Epoch     2, train loss 0.962114, train error 35.75,  val loss 1.208207, percent error 45.80
# Epoch     3, train loss 0.837808, train error 31.30,  val loss 1.176144, percent error 45.80
# Epoch     4, train loss 0.793636, train error 29.47,  val loss 1.227664, percent error 45.40
# Epoch     5, train loss 0.654998, train error 23.70,  val loss 1.141719, percent error 41.90
# Epoch     6, train loss 0.622923, train error 21.97,  val loss 1.189352, percent error 44.10
# Epoch     7, train loss 0.600615, train error 22.72,  val loss 1.305698, percent error 42.50
# Epoch     8, train loss 0.468010, train error 16.68,  val loss 1.192472, percent error 41.00
# Epoch     9, train loss 0.440237, train error 15.82,  val loss 1.145970, percent error 38.00
# Epoch    10, train loss 0.423120, train error 15.97,  val loss 1.304589, percent error 41.20
# Epoch    11, train loss 0.313522, train error 10.82,  val loss 1.235553, percent error 39.00
# Epoch    12, train loss 0.401431, train error 14.68,  val loss 1.406819, percent error 39.60
# Epoch    13, train loss 0.362468, train error 13.30,  val loss 1.404534, percent error 39.70
# Epoch    14, train loss 0.330033, train error 12.38,  val loss 1.463340, percent error 38.90
# Epoch    15, train loss 0.285376, train error 10.10,  val loss 1.443399, percent error 39.10
# Epoch    16, train loss 0.221333, train error 7.88,  val loss 1.450637, percent error 38.50
# Epoch    17, train loss 0.191871, train error 6.72,  val loss 1.345919, percent error 36.00
# Epoch    18, train loss 0.214385, train error 7.57,  val loss 1.511872, percent error 35.60
# Epoch    19, train loss 0.228563, train error 8.18,  val loss 1.651752, percent error 35.50
# Epoch    20, train loss 0.062505, train error 1.32,  val loss 1.403754, percent error 33.90
# Epoch    21, train loss 0.028116, train error 0.10,  val loss 1.392390, percent error 33.10
# Epoch    22, train loss 0.018091, train error 0.00,  val loss 1.397741, percent error 32.50
# Epoch    23, train loss 0.014371, train error 0.00,  val loss 1.427533, percent error 33.20
# Epoch    24, train loss 0.012052, train error 0.00,  val loss 1.439600, percent error 32.50
# Epoch    25, train loss 0.011103, train error 0.00,  val loss 1.451382, percent error 32.60
# Epoch    26, train loss 0.009612, train error 0.00,  val loss 1.468047, percent error 32.80
# Epoch    27, train loss 0.008854, train error 0.00,  val loss 1.476795, percent error 32.20
# Epoch    28, train loss 0.008115, train error 0.00,  val loss 1.490358, percent error 32.40
# Epoch    29, train loss 0.007595, train error 0.00,  val loss 1.499552, percent error 32.70
# Epoch    30, train loss 0.007110, train error 0.00,  val loss 1.506746, percent error 32.10
# Epoch    31, train loss 0.006640, train error 0.00,  val loss 1.521625, percent error 32.30
# Epoch    32, train loss 0.006269, train error 0.00,  val loss 1.527771, percent error 32.20
# Epoch    33, train loss 0.005944, train error 0.00,  val loss 1.534187, percent error 32.30
# Epoch    34, train loss 0.005619, train error 0.00,  val loss 1.543667, percent error 32.20
# Epoch    35, train loss 0.005349, train error 0.00,  val loss 1.556150, percent error 32.10
# Epoch    36, train loss 0.005131, train error 0.00,  val loss 1.562093, percent error 31.90
# Epoch    37, train loss 0.004910, train error 0.00,  val loss 1.567583, percent error 32.50
# Epoch    38, train loss 0.004683, train error 0.00,  val loss 1.575975, percent error 32.10
# Epoch    39, train loss 0.004515, train error 0.00,  val loss 1.583321, percent error 32.70
# Epoch    40, train loss 0.004394, train error 0.00,  val loss 1.587521, percent error 32.20
# Epoch    41, train loss 0.004314, train error 0.00,  val loss 1.591881, percent error 32.10
# Epoch    42, train loss 0.004231, train error 0.00,  val loss 1.594805, percent error 32.20
# Epoch    43, train loss 0.004157, train error 0.00,  val loss 1.596623, percent error 32.00
# Epoch    44, train loss 0.004081, train error 0.00,  val loss 1.599972, percent error 32.10
# Epoch    45, train loss 0.004010, train error 0.00,  val loss 1.604222, percent error 32.20
# Epoch    46, train loss 0.003940, train error 0.00,  val loss 1.608000, percent error 32.10
# Epoch    47, train loss 0.003872, train error 0.00,  val loss 1.611074, percent error 31.90
# Epoch    48, train loss 0.003809, train error 0.00,  val loss 1.613553, percent error 31.90
# Epoch    49, train loss 0.003745, train error 0.00,  val loss 1.616475, percent error 32.00
# Epoch    50, train loss 0.003686, train error 0.00,  val loss 1.619405, percent error 32.00
# Epoch    51, train loss 0.003628, train error 0.00,  val loss 1.623128, percent error 31.90
# Epoch    52, train loss 0.003570, train error 0.00,  val loss 1.624905, percent error 31.90
# Epoch    53, train loss 0.003515, train error 0.00,  val loss 1.628247, percent error 32.20
# Epoch    54, train loss 0.003461, train error 0.00,  val loss 1.631331, percent error 32.00
# Epoch    55, train loss 0.003411, train error 0.00,  val loss 1.634064, percent error 32.10
# Epoch    56, train loss 0.003360, train error 0.00,  val loss 1.636540, percent error 32.10
# Epoch    57, train loss 0.003310, train error 0.00,  val loss 1.638947, percent error 32.00
# Epoch    58, train loss 0.003263, train error 0.00,  val loss 1.641335, percent error 32.20
# Epoch    59, train loss 0.003217, train error 0.00,  val loss 1.643631, percent error 32.20
# Epoch    60, train loss 0.003193, train error 0.00,  val loss 1.645313, percent error 32.30
# Epoch    61, train loss 0.003170, train error 0.00,  val loss 1.647104, percent error 32.10
# Epoch    62, train loss 0.003149, train error 0.00,  val loss 1.648089, percent error 32.20
# Epoch    63, train loss 0.003127, train error 0.00,  val loss 1.649310, percent error 32.10
# Epoch    64, train loss 0.003106, train error 0.00,  val loss 1.651257, percent error 32.30
# Epoch    65, train loss 0.003085, train error 0.00,  val loss 1.651808, percent error 32.20
# Epoch    66, train loss 0.003064, train error 0.00,  val loss 1.652969, percent error 32.30
# Epoch    67, train loss 0.003043, train error 0.00,  val loss 1.655167, percent error 32.20
# Epoch    68, train loss 0.003023, train error 0.00,  val loss 1.655710, percent error 32.40
# Epoch    69, train loss 0.003003, train error 0.00,  val loss 1.657170, percent error 32.30
# Epoch    70, train loss 0.002984, train error 0.00,  val loss 1.658288, percent error 32.50
# Epoch    71, train loss 0.002964, train error 0.00,  val loss 1.659312, percent error 32.60
# Epoch    72, train loss 0.002945, train error 0.00,  val loss 1.660467, percent error 32.60
# Epoch    73, train loss 0.002926, train error 0.00,  val loss 1.662232, percent error 32.60
# Epoch    74, train loss 0.002907, train error 0.00,  val loss 1.663436, percent error 32.60
# Epoch    75, train loss 0.002889, train error 0.00,  val loss 1.664325, percent error 32.60
# Epoch    76, train loss 0.002871, train error 0.00,  val loss 1.665441, percent error 32.60
# Epoch    77, train loss 0.002852, train error 0.00,  val loss 1.666736, percent error 32.60
# Epoch    78, train loss 0.002834, train error 0.00,  val loss 1.667704, percent error 32.60
# Epoch    79, train loss 0.002817, train error 0.00,  val loss 1.668913, percent error 32.60
# Epoch    80, train loss 0.002808, train error 0.00,  val loss 1.669587, percent error 32.60
# Epoch    81, train loss 0.002799, train error 0.00,  val loss 1.670111, percent error 32.60
# Epoch    82, train loss 0.002790, train error 0.00,  val loss 1.670895, percent error 32.60
# Epoch    83, train loss 0.002782, train error 0.00,  val loss 1.671415, percent error 32.60
# Epoch    84, train loss 0.002773, train error 0.00,  val loss 1.672042, percent error 32.60
# Epoch    85, train loss 0.002765, train error 0.00,  val loss 1.672493, percent error 32.60
# Epoch    86, train loss 0.002756, train error 0.00,  val loss 1.673295, percent error 32.60
# Epoch    87, train loss 0.002748, train error 0.00,  val loss 1.673834, percent error 32.60
# Epoch    88, train loss 0.002739, train error 0.00,  val loss 1.674167, percent error 32.60
# Epoch    89, train loss 0.002731, train error 0.00,  val loss 1.674693, percent error 32.70
# Epoch    90, train loss 0.002723, train error 0.00,  val loss 1.675346, percent error 32.70
# Epoch    91, train loss 0.002715, train error 0.00,  val loss 1.676083, percent error 32.60
# Epoch    92, train loss 0.002707, train error 0.00,  val loss 1.676436, percent error 32.60
# Epoch    93, train loss 0.002699, train error 0.00,  val loss 1.677027, percent error 32.70
# Epoch    94, train loss 0.002691, train error 0.00,  val loss 1.677661, percent error 32.60
# Epoch    95, train loss 0.002683, train error 0.00,  val loss 1.677922, percent error 32.80
# Epoch    96, train loss 0.002674, train error 0.00,  val loss 1.678602, percent error 32.60
# Epoch    97, train loss 0.002667, train error 0.00,  val loss 1.679158, percent error 32.70
# Epoch    98, train loss 0.002659, train error 0.00,  val loss 1.679819, percent error 32.70
# Epoch    99, train loss 0.002651, train error 0.00,  val loss 1.680397, percent error 32.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
