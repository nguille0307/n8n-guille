# %% [markdown]
# <a href="https://colab.research.google.com/github/nguille0307/n8n-guille/blob/master/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-le848xxn
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-le848xxn
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=cdae562d5d6229d5f4b3fe9cfdf2a4e34fb98b49ec05bd1c264f1bbbbd018559
#   Stored in directory: /tmp/pip-ephem-wheel-cache-870lmv92/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(1,  15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),

    # Capa 2: entrada (batch, 15 canales, largo 19) → salida (batch, 15 canales, largo 9)
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),

    # Capa 3: entrada (batch, 15 canales, largo 9) → salida (batch, 15 canales, largo 4)
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),

    # Flatten: (batch, 15 canales, largo 4) → (batch, 60)
    nn.Flatten(),

    # Clasificador final
    nn.Linear(60, 10),
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.186616, train error 83.82,  val loss 2.180186, percent error 82.50
# Epoch     1, train loss 1.728080, train error 69.80,  val loss 1.758906, percent error 73.80
# Epoch     2, train loss 1.382208, train error 55.42,  val loss 1.389425, percent error 56.00
# Epoch     3, train loss 1.310005, train error 54.62,  val loss 1.308490, percent error 55.30
# Epoch     4, train loss 1.193437, train error 48.38,  val loss 1.196005, percent error 49.70
# Epoch     5, train loss 1.161236, train error 47.97,  val loss 1.203690, percent error 50.40
# Epoch     6, train loss 1.007758, train error 40.70,  val loss 1.036256, percent error 41.50
# Epoch     7, train loss 0.924066, train error 36.47,  val loss 0.970234, percent error 39.40
# Epoch     8, train loss 0.884619, train error 35.32,  val loss 0.898336, percent error 35.00
# Epoch     9, train loss 0.751271, train error 29.90,  val loss 0.799766, percent error 32.70
# Epoch    10, train loss 0.717201, train error 29.47,  val loss 0.787330, percent error 33.40
# Epoch    11, train loss 0.709127, train error 28.03,  val loss 0.777742, percent error 31.10
# Epoch    12, train loss 0.565683, train error 22.47,  val loss 0.640121, percent error 26.20
# Epoch    13, train loss 0.552309, train error 22.18,  val loss 0.627941, percent error 23.60
# Epoch    14, train loss 0.516942, train error 20.80,  val loss 0.618986, percent error 24.80
# Epoch    15, train loss 0.378226, train error 14.55,  val loss 0.502831, percent error 18.80
# Epoch    16, train loss 0.397076, train error 15.05,  val loss 0.515142, percent error 19.90
# Epoch    17, train loss 0.333440, train error 12.40,  val loss 0.479785, percent error 17.70
# Epoch    18, train loss 0.343295, train error 13.00,  val loss 0.467659, percent error 17.70
# Epoch    19, train loss 0.311102, train error 11.38,  val loss 0.456199, percent error 15.50
# Epoch    20, train loss 0.257239, train error 9.32,  val loss 0.405768, percent error 14.90
# Epoch    21, train loss 0.257015, train error 9.68,  val loss 0.427563, percent error 15.10
# Epoch    22, train loss 0.218700, train error 7.82,  val loss 0.409641, percent error 14.10
# Epoch    23, train loss 0.209907, train error 7.57,  val loss 0.404299, percent error 14.50
# Epoch    24, train loss 0.193171, train error 6.78,  val loss 0.393147, percent error 13.60
# Epoch    25, train loss 0.184823, train error 6.40,  val loss 0.372433, percent error 12.20
# Epoch    26, train loss 0.198381, train error 7.38,  val loss 0.389694, percent error 13.20
# Epoch    27, train loss 0.173364, train error 5.95,  val loss 0.396240, percent error 12.20
# Epoch    28, train loss 0.207434, train error 7.82,  val loss 0.433844, percent error 14.40
# Epoch    29, train loss 0.219871, train error 7.62,  val loss 0.446638, percent error 14.40
# Epoch    30, train loss 0.187674, train error 6.88,  val loss 0.444740, percent error 14.00
# Epoch    31, train loss 0.180539, train error 6.75,  val loss 0.393106, percent error 12.40
# Epoch    32, train loss 0.150801, train error 5.28,  val loss 0.387048, percent error 11.80
# Epoch    33, train loss 0.134408, train error 4.25,  val loss 0.368554, percent error 11.60
# Epoch    34, train loss 0.161497, train error 6.07,  val loss 0.394820, percent error 13.10
# Epoch    35, train loss 0.134953, train error 4.80,  val loss 0.378616, percent error 11.30
# Epoch    36, train loss 0.146183, train error 4.97,  val loss 0.398928, percent error 12.30
# Epoch    37, train loss 0.129649, train error 4.43,  val loss 0.356649, percent error 11.60
# Epoch    38, train loss 0.116956, train error 3.95,  val loss 0.378973, percent error 10.70
# Epoch    39, train loss 0.124402, train error 4.45,  val loss 0.376559, percent error 11.00
# Epoch    40, train loss 0.104114, train error 3.22,  val loss 0.376945, percent error 10.60
# Epoch    41, train loss 0.097201, train error 2.97,  val loss 0.368738, percent error 10.30
# Epoch    42, train loss 0.099504, train error 3.00,  val loss 0.381141, percent error 11.50
# Epoch    43, train loss 0.092926, train error 2.70,  val loss 0.372844, percent error 10.60
# Epoch    44, train loss 0.093913, train error 3.05,  val loss 0.384305, percent error 11.10
# Epoch    45, train loss 0.094736, train error 2.80,  val loss 0.368061, percent error 10.90
# Epoch    46, train loss 0.093050, train error 2.78,  val loss 0.366326, percent error 10.60
# Epoch    47, train loss 0.094821, train error 3.18,  val loss 0.379685, percent error 10.30
# Epoch    48, train loss 0.090621, train error 3.18,  val loss 0.373820, percent error 10.20
# Epoch    49, train loss 0.090134, train error 2.75,  val loss 0.393304, percent error 11.80
# Epoch    50, train loss 0.085946, train error 2.62,  val loss 0.374712, percent error 10.90
# Epoch    51, train loss 0.082201, train error 2.62,  val loss 0.386707, percent error 10.50
# Epoch    52, train loss 0.085033, train error 2.57,  val loss 0.379224, percent error 10.70
# Epoch    53, train loss 0.080374, train error 2.38,  val loss 0.391219, percent error 10.40
# Epoch    54, train loss 0.082958, train error 2.55,  val loss 0.405885, percent error 10.60
# Epoch    55, train loss 0.077706, train error 2.50,  val loss 0.381667, percent error 10.10
# Epoch    56, train loss 0.075975, train error 2.60,  val loss 0.393853, percent error 10.50
# Epoch    57, train loss 0.074603, train error 2.07,  val loss 0.387020, percent error 10.70
# Epoch    58, train loss 0.082987, train error 2.68,  val loss 0.391864, percent error 10.40
# Epoch    59, train loss 0.070924, train error 1.93,  val loss 0.397322, percent error 10.90
# Epoch    60, train loss 0.068954, train error 2.00,  val loss 0.388996, percent error 10.20
# Epoch    61, train loss 0.063900, train error 1.70,  val loss 0.389044, percent error 10.80
# Epoch    62, train loss 0.066051, train error 1.75,  val loss 0.394354, percent error 10.40
# Epoch    63, train loss 0.062860, train error 1.57,  val loss 0.392255, percent error 10.10
# Epoch    64, train loss 0.062326, train error 1.62,  val loss 0.394224, percent error 10.30
# Epoch    65, train loss 0.062388, train error 1.70,  val loss 0.396686, percent error 10.70
# Epoch    66, train loss 0.060691, train error 1.55,  val loss 0.392383, percent error 10.20
# Epoch    67, train loss 0.060716, train error 1.60,  val loss 0.400696, percent error 10.90
# Epoch    68, train loss 0.061571, train error 1.70,  val loss 0.395434, percent error 9.90
# Epoch    69, train loss 0.059282, train error 1.60,  val loss 0.398536, percent error 10.50
# Epoch    70, train loss 0.058335, train error 1.47,  val loss 0.407759, percent error 10.80
# Epoch    71, train loss 0.059075, train error 1.57,  val loss 0.404133, percent error 10.20
# Epoch    72, train loss 0.058151, train error 1.45,  val loss 0.405787, percent error 10.40
# Epoch    73, train loss 0.057163, train error 1.47,  val loss 0.403217, percent error 10.40
# Epoch    74, train loss 0.057323, train error 1.62,  val loss 0.407327, percent error 10.20
# Epoch    75, train loss 0.056177, train error 1.30,  val loss 0.397915, percent error 10.30
# Epoch    76, train loss 0.058447, train error 1.55,  val loss 0.404783, percent error 10.90
# Epoch    77, train loss 0.057196, train error 1.38,  val loss 0.404514, percent error 10.50
# Epoch    78, train loss 0.055567, train error 1.50,  val loss 0.408285, percent error 10.70
# Epoch    79, train loss 0.052146, train error 1.38,  val loss 0.402897, percent error 10.50
# Epoch    80, train loss 0.051488, train error 1.25,  val loss 0.406782, percent error 10.40
# Epoch    81, train loss 0.051031, train error 1.18,  val loss 0.405794, percent error 10.30
# Epoch    82, train loss 0.050902, train error 1.12,  val loss 0.410970, percent error 10.50
# Epoch    83, train loss 0.050249, train error 1.18,  val loss 0.408130, percent error 10.20
# Epoch    84, train loss 0.050177, train error 1.15,  val loss 0.411041, percent error 10.70
# Epoch    85, train loss 0.050229, train error 1.18,  val loss 0.407078, percent error 10.40
# Epoch    86, train loss 0.050570, train error 1.20,  val loss 0.413149, percent error 10.40
# Epoch    87, train loss 0.049917, train error 1.15,  val loss 0.414181, percent error 10.20
# Epoch    88, train loss 0.048853, train error 1.07,  val loss 0.411595, percent error 10.40
# Epoch    89, train loss 0.049134, train error 1.15,  val loss 0.411614, percent error 10.00
# Epoch    90, train loss 0.048250, train error 1.10,  val loss 0.414789, percent error 10.40
# Epoch    91, train loss 0.047949, train error 1.10,  val loss 0.412022, percent error 10.30
# Epoch    92, train loss 0.048233, train error 1.03,  val loss 0.412219, percent error 10.40
# Epoch    93, train loss 0.049098, train error 1.22,  val loss 0.421030, percent error 10.00
# Epoch    94, train loss 0.047413, train error 1.05,  val loss 0.415602, percent error 10.30
# Epoch    95, train loss 0.047483, train error 1.10,  val loss 0.415507, percent error 9.80
# Epoch    96, train loss 0.046770, train error 1.10,  val loss 0.414840, percent error 10.30
# Epoch    97, train loss 0.046465, train error 1.05,  val loss 0.416393, percent error 10.30
# Epoch    98, train loss 0.046661, train error 1.07,  val loss 0.415678, percent error 10.30
# Epoch    99, train loss 0.047330, train error 1.15,  val loss 0.420106, percent error 10.00
